# %%
# Grounding 을 사용해 보려 했으나, 차라리 thinking exp model사용이 더 나을 것 같다는 결론
import google.generativeai as genai
import google.ai.generativelanguage as glm
import os
from dotenv import load_dotenv

load_dotenv()

genai.configure(api_key=os.environ.get('GOOGLE_API_KEY'))

# %%
model = genai.GenerativeModel('gemini-2.0-flash-thinking-exp-01-21')

response = model.generate_content(contents="2025년 3월 비트코인 가격이 상승할지 하락할지 예측하고, 그 근거를 300 단어 이내로 설명하세요.")
print(response.text)
# Out:
# ## 2025년 3월 비트코인 가격 예측 (상승)
#
# 2025년 3월 비트코인 가격은 **상승**할 가능성이 높다고 예측합니다.  주요 근거는 다음과 같습니다.
#
# **1. 반감기 효과:** 2024년 4월로 예상되는 비트코인 반감기는 채굴 보상을 절반으로 줄여 신규 공급량을 감소시킵니다. 역사적으로 반감기 이후 1년~1년 반 동안 공급 감소와 수요 증가가 맞물려 가격 상승을 견인했습니다. 2025년 3월은 반감기 효과가 본격적으로 나타날 시점으로 예상됩니다.
#
# **2. 기관 투자 확대:**  블랙록, 피델리티 등 거대 금융 기관들의 비트코인 현물 ETF 출시 및 관심 증가는 기관 투자 자금 유입을 가속화할 것입니다.  이는 비트코인 시장의 성숙도를 높이고, 장기적인 가격 상승 기반을 다지는 요인입니다.
#
# **3. 거시경제 불확실성 지속:**  높은 인플레이션과 금리 인상 가능성 등 거시경제 불확실성은 안전 자산으로서의 비트코인 매력을 부각시킬 수 있습니다.  전통 금융 시스템에 대한 불안감이 커질수록 비트코인은 대체 투자 수단으로 각광받으며 수요가 증가할 수 있습니다.
#
# 물론, 예상치 못한 규제 변화, 글로벌 경제 위기 등 하락 요인도 존재합니다. 하지만 현재 시장 상황과 과거 사례를 종합적으로 고려했을 때, 2025년 3월 비트코인 가격은 상승 추세를 이어갈 가능성이 더 높다고 판단됩니다.  **투자는 항상 위험을 수반하므로, 신중한 판단이 필요합니다.**

# %%
response = model.generate_content(contents="2025년 3월 테슬라 주가의 변동 방향성을 예측하고, 주가 흐름에 대한 그래프를 간략하게 보여주면서 그 근거를 500 단어 이내로 설명하세요.")
print(response.text)
# Out:
# ## 2025년 3월 테슬라 주가 변동 방향성 예측 및 근거
#
# **예상 주가 흐름 (간략 그래프):**
#
# ```
#      /--- (약간 상승 또는 횡보)
#     /
# ---/--------------------- 시간 (2025년 3월)
# ```
#
# **근거:**
#
# 2025년 3월 테슬라 주가 방향성을 예측하기 위해서는 다양한 요소를 종합적으로 고려해야 합니다. 현재 시점(2023년 10월)에서 1년 반 이상 후의 미래를 정확히 예측하는 것은 불가능에 가깝지만, 현재 시장 상황과 테슬라의 사업 모델, 미래 성장 동력 등을 분석하여 가능한 시나리오와 그 근거를 제시하고자 합니다.
#
# **긍정적 요인 (주가 상승 가능성):**
#
# * **지속적인 전기차 시장 성장:** 전 세계적인 환경 규제 강화와 소비자 인식 변화로 전기차 시장은 장기적으로 성장할 가능성이 매우 높습니다. 테슬라는 전기차 시장의 선두 주자로서 이러한 성장의 가장 큰 수혜를 받을 수 있습니다.
# * **모델 3, 모델 Y의 견고한 판매량:**  테슬라의 주력 모델인 모델 3와 모델 Y는 여전히 높은 수요를 유지하고 있으며, 향후 페이스리프트 모델 출시 및 생산 효율성 증대를 통해 수익성을 더욱 개선할 수 있습니다.
# * **신규 모델 및 기술 혁신:** 사이버트럭 출시 (일정 지연 가능성 존재), 로보택시 개발 진전, 차세대 배터리 기술 개발 등은 테슬라의 미래 성장 동력이 될 수 있습니다. 특히 로보택시 상용화는 테슬라의 사업 모델을 완전히 변화시킬 잠재력을 가지고 있습니다.
# * **에너지 사업 성장:**  태양광, 에너지 저장 장치(ESS) 사업 또한 꾸준히 성장하고 있으며, 테슬라는 에너지 사업 부문에서도 경쟁력을 강화하고 있습니다.
# * **AI 및 소프트웨어 역량 강화:**  테슬라는 자율주행 기술을 포함한 AI 분야에서 선도적인 위치를 점하고 있으며, 소프트웨어 중심의 혁신을 통해 새로운 가치를 창출할 수 있습니다.
# ...
